# %% [markdown]
# # Lab | APIs

# %% [markdown]
# In order to use the `Spotify` API (`SpotiPy`), create an account in `Spotify` and follow [these](https://developer.spotify.com/documentation/general/guides/app-settings/) steps.

# %% [markdown]
# ## Authentication and initializing the API

# %% [markdown]
# Save your client ID and your client secret in your preferred way, and read it or load it into the following variables:

# %%
import pandas as pd
import json

# %%
CLIENT_ID = "<introduce your client id>"
CLIENT_SECRET = "<introduce your client secret>"

# %%
CLIENT_ID = "4109b2d9f5014671863bb2df1d1fbdd3"
CLIENT_SECRET = "5cb719fae80c4191a9c0b288f51bfe50"

# %%
# If you havent done so, install the spotipy wrapper
# !pip install spotipy
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Once you have done it, we will start initializing the API.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,
                                                           client_secret=CLIENT_SECRET))

# %% [markdown]
# ## Using the search method

# %% [markdown]
# Now, let's use the search method by introducing a "query". For example, let's try searching for "Lady Gaga":

# %%
results = sp.search(q='Pearl Jam', limit=49)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Pearl+Jam&type=track&offset=0&limit=49',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1w5Kfo2jwwIPruYS2UWh56'},
#        'href': 'https://api.spotify.com/v1/artists/1w5Kfo2jwwIPruYS2UWh56',
#        'id': '1w5Kfo2jwwIPruYS2UWh56',
#        'name': 'Pearl Jam',
#        'type': 'artist',
#        'uri': 'spotify:artist:1w5Kfo2jwwIPruYS2UWh56'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
# ...

# %%
results.keys() # We can see that we only have tracks
# Out:
# dict_keys(['tracks'])

# %%
print(len(results["tracks"].keys()))
results["tracks"].keys() # Let's check the values
# Out:
# 7
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
results["tracks"]["href"] # Query we have searched
# Out:
# 'https://api.spotify.com/v1/search?query=Pearl+Jam&type=track&offset=0&limit=49'

# %%
results["tracks"]["items"] #items (actual tracks)
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1w5Kfo2jwwIPruYS2UWh56'},
#      'href': 'https://api.spotify.com/v1/artists/1w5Kfo2jwwIPruYS2UWh56',
#      'id': '1w5Kfo2jwwIPruYS2UWh56',
#      'name': 'Pearl Jam',
#      'type': 'artist',
#      'uri': 'spotify:artist:1w5Kfo2jwwIPruYS2UWh56'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
# ...

# %%
results["tracks"]["limit"]#Limit we have chosen
# Out:
# 49

# %%
results["tracks"]["next"] #link to the next page (next 50 tracks)
# Out:
# 'https://api.spotify.com/v1/search?query=Pearl+Jam&type=track&offset=49&limit=49'

# %%
results["tracks"]["offset"] # Actual offset (starting point)
# Out:
# 0

# %%
results["tracks"]["previous"] #Previous search

# %%
results["tracks"]["total"] # Number of matches
# Out:
# 905

# %%
results["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1w5Kfo2jwwIPruYS2UWh56'},
#   'href': 'https://api.spotify.com/v1/artists/1w5Kfo2jwwIPruYS2UWh56',
#   'id': '1w5Kfo2jwwIPruYS2UWh56',
#   'name': 'Pearl Jam',
#   'type': 'artist',
#   'uri': 'spotify:artist:1w5Kfo2jwwIPruYS2UWh56'}]

# %%
results['tracks']['items'][0]['album']['artists'][0]['id']
# Out:
# '1w5Kfo2jwwIPruYS2UWh56'

# %% [markdown]
# ## Exploring the tracks

# %%
first_track = results["tracks"]["items"][0] # Explore the first song

# %%
df = pd.DataFrame([first_track])
df = df.stack().unstack(-2)

# Display the pretty view of the song details
print(df)
# Out:
#                                                                    0
# album              {'album_type': 'album', 'artists': [{'external...
# artists            [{'external_urls': {'spotify': 'https://open.s...
# available_markets  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# disc_number                                                        1
# duration_ms                                                   342653
# explicit                                                       False
# external_ids                                {'isrc': 'USSM19100412'}
# external_urls      {'spotify': 'https://open.spotify.com/track/5X...
# href               https://api.spotify.com/v1/tracks/5Xak5fmy089t...
# id                                            5Xak5fmy089t0FYmh3VJiY
# is_local                                                       False
# name                                                           Black
# popularity                                                        73
# ...

# %%
results["tracks"]["items"][0].keys() # We will focus on album, artists, id, name, popularity, type and uri
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
# Track artists
results["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1w5Kfo2jwwIPruYS2UWh56'},
#   'href': 'https://api.spotify.com/v1/artists/1w5Kfo2jwwIPruYS2UWh56',
#   'id': '1w5Kfo2jwwIPruYS2UWh56',
#   'name': 'Pearl Jam',
#   'type': 'artist',
#   'uri': 'spotify:artist:1w5Kfo2jwwIPruYS2UWh56'}]

# %%
# Track artists names
for artist in results["tracks"]["items"][0]["artists"]:
    print(artist["name"])
# Out:
# Pearl Jam

# %%
# Track ID
results["tracks"]["items"][0]["id"]
# Out:
# '5Xak5fmy089t0FYmh3VJiY'

# %%
# Track name
count = results["tracks"]["limit"]
results["tracks"]["items"][0]["name"]

for i in range(count):
    print(results["tracks"]["items"][i]["name"])
# Out:
# Black
# Even Flow
# Yellow Ledbetter
# Alive
# Jeremy
# Just Breathe
# Elderly Woman Behind the Counter in a Small Town - Remastered
# Last Kiss
# Daughter - Remastered
# Better Man
# Do the Evolution
# Once
# Wreckage
# State of Love and Trust
# Release
# Wreckage
# Wishlist
# Daughter
# Dark Matter
# Garden
# Yellow Ledbetter
# Animal - Remastered
# Given to Fly
# Dissident - Remastered
# Go - Remastered
# Corduroy - Remastered
# Sirens
# Nothingman - Remastered
# Black - Live MTV Unplugged
# Why Go
# Hunger Strike
# Rearviewmirror - Remastered
# Soldier of Love
# Better Man
# Deep
# Breath
# Scared Of Fear
# Present Tense
# Won't Tell
# Glorified G - Remastered
# Leash - Remastered
# Better Man - Live
# The Fixer
# Light Years
# Porch
# Even Flow
# Oceans
# In Hiding
# Elderly Woman Behind the Counter in a Small Town - Acoustic Version

# %%
# Popularity index
results["tracks"]["items"][0]["popularity"] 
x = results["tracks"]["limit"]

for i in range(x):
    print(f"Name:  {results["tracks"]["items"][i]["name"]} popularity: {results["tracks"]["items"][i]["popularity"]}")
# Out:
# Name:  Black popularity: 73
# Name:  Even Flow popularity: 78
# Name:  Yellow Ledbetter popularity: 68
# Name:  Alive popularity: 75
# Name:  Jeremy popularity: 70
# Name:  Just Breathe popularity: 65
# Name:  Elderly Woman Behind the Counter in a Small Town - Remastered popularity: 63
# Name:  Last Kiss popularity: 71
# Name:  Daughter - Remastered popularity: 67
# Name:  Better Man popularity: 66
# Name:  Do the Evolution popularity: 57
# Name:  Once popularity: 58
# Name:  Wreckage popularity: 54
# Name:  State of Love and Trust popularity: 53
# Name:  Release popularity: 54
# Name:  Wreckage popularity: 62
# Name:  Wishlist popularity: 56
# Name:  Daughter popularity: 46
# Name:  Dark Matter popularity: 59
# Name:  Garden popularity: 54
# Name:  Yellow Ledbetter popularity: 39
# Name:  Animal - Remastered popularity: 56
# Name:  Given to Fly popularity: 57
# Name:  Dissident - Remastered popularity: 55
# Name:  Go - Remastered popularity: 53
# ...

# %% [markdown]
# Spotify songs are identified by either a "url", a "uri", or an "id".
#
# - The `id` is an alphanumeric code, and it's the nuclear part of the identifier.
#
# - The `uri` contains "spotify:track" before the id. An uri is useful because it can be searched manually in the Spotify app.
#
# - The `url` is a link to the song on the Spotify web player.

# %%
results["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:5Xak5fmy089t0FYmh3VJiY'

# %% [markdown]
# ## Exercise 1: Discovering New Music through Your Favorite Artists
#
# **Objective:**
# Uncover new music by exploring the top tracks of your favorite artists and their related artists.
#
# **Instructions:**
#
# 1. **List Your Favorite Artists**:
#     - Make a list of your three favorite artists and store it in a variable named `artists`.
#     - Example: `artists = ["Los Fabulosos Cadillacs", "Manu Chao", "Muchachito Bombo Infierno"]`.

# %%
artists = ["Pearl Jam", "Nirvana", "Metallica"]

# %% [markdown]
# 2. **Fetch Top Tracks**:
#     - Write a function named `get_top_tracks`.
#     - This function should accept an artist's name and return the name of the first 5 top tracks by that artist.
#     - Use the function `get_top_tracks` to get the first 5 top tracks for each artist in your `artists` list and store the results in a new list named `top_tracks_list`.

# %%
def get_top_tracks(banda):
    results = sp.search(q=banda, limit=50)
    name_and_pop = {results["tracks"]["items"][i]["name"]:results["tracks"]["items"][i]["popularity"] for i in range(len(results["tracks"]["items"]))}
    top_5_max_items = dict(sorted(name_and_pop.items(), key=lambda item: item[1], reverse=True)[:5])
    return top_5_max_items

# %%
get_top_tracks("Nirvana")
# Out:
# {'Dumb': 75,
#  'The Man Who Sold The World - Live': 74,
#  'All Apologies': 72,
#  'Love Buzz': 70,
#  'Something In The Way': 68}

# %% [markdown]
# 3. **Discover Related Artists**:
#     - Write a function named `find_related_artists`.
#     - This function should accept an artist's name and return the names of the first 5 artists related to the provided artist.
#     - Store the results in a list named `related_artists_list`.
#
# **Challenge:**
# Combine the above steps to create a playlist that includes the top tracks of your favorite artists and the top tracks of the artists related to them.

# %%
results['tracks']['items'][0]['album']['artists'][0]['id']
# Out:
# '1w5Kfo2jwwIPruYS2UWh56'

# %%
sp.artist_albums("1w5Kfo2jwwIPruYS2UWh56")
# Out:
# {'href': 'https://api.spotify.com/v1/artists/1w5Kfo2jwwIPruYS2UWh56/albums?include_groups=album,single,compilation,appears_on&offset=0&limit=20',
#  'items': [{'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1w5Kfo2jwwIPruYS2UWh56'},
#      'href': 'https://api.spotify.com/v1/artists/1w5Kfo2jwwIPruYS2UWh56',
#      'id': '1w5Kfo2jwwIPruYS2UWh56',
#      'name': 'Pearl Jam',
#      'type': 'artist',
#      'uri': 'spotify:artist:1w5Kfo2jwwIPruYS2UWh56'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
# ...

# %%
data = sp.artist_related_artists("1w5Kfo2jwwIPruYS2UWh56")

related_artists = [artist['name'] for artist in data["artists"]]

related_artists
# Out:
# ['Stone Temple Pilots',
#  'Soundgarden',
#  'Temple Of The Dog',
#  'Chris Cornell',
#  'Alice In Chains',
#  'Eddie Vedder',
#  'Audioslave',
#  'Bush',
#  'The Smashing Pumpkins',
#  'Faith No More',
#  'Blind Melon',
#  'Rage Against The Machine',
#  "Jane's Addiction",
#  'Silverchair',
#  'Foo Fighters',
#  'Incubus',
#  'Queens of the Stone Age',
#  'Velvet Revolver',
#  'Candlebox',
#  'Live']

# %%
def find_related_artists(banda):
    results = sp.search(q=banda, limit=1)
    data = sp.artist_related_artists(results['tracks']['items'][0]['album']['artists'][0]['id'])
    artists_related_list = [artist['name'] for artist in data["artists"]]
    return artists_related_list

# %%
related_atists_list = find_related_artists("Pearl Jam")

# %%
for artist in related_atists_list:
    print(artist,get_top_tracks(artist))
# Out:
# Stone Temple Pilots {'Interstate Love Song - 2019 Remaster': 73, 'Creep - 2017 Remaster': 66, 'Plush - 2017 Remaster': 64, 'Vasoline - 2019 Remaster': 62, "Trippin' on a Hole in a Paper Heart": 62}
# Soundgarden {'Like a Stone': 79, 'Show Me How to Live': 68, 'Spoonman': 66, 'Creep - 2017 Remaster': 66, 'Plush - 2017 Remaster': 64}
# Temple Of The Dog {'Hunger Strike': 64, 'The Temple Of The King': 58, 'Say Hello 2 Heaven': 57, 'Temple of Love - 1992': 55, 'Call Me A Dog': 52}
# Chris Cornell {'Like a Stone': 79, 'Black Hole Sun': 78, 'I Am the Highway': 64, 'Hunger Strike': 64, 'Nothing Compares 2 U - Live At SiriusXM/2015': 57}
# Alice In Chains {'Black Hole Sun': 78, 'Man in the Box': 76, 'Would? (2022 Remaster)': 75, 'Rooster (2022 Remaster)': 71, 'Unsainted': 71}
# Eddie Vedder {'Jeremy': 70, 'Yellow Ledbetter': 68, 'Society': 67, 'Just Breathe': 65, 'Elderly Woman Behind the Counter in a Small Town - Remastered': 63}
# ...

# %% [markdown]
# **Hint Section for 3. **Discover Related Artists**:**
#
# 1. **Getting Artist ID**:
#     - Remember that every artist on Spotify has a unique identifier: their `id`. To get the related artists, you first need to fetch the ID of the given artist.
#     - Consider using the `sp.search` method to query the artist's name. The method requires a `q` parameter, which is your query (in this case, the artist's name). It also has a `limit` parameter, which specifies the number of tracks it returns. In this case, 1 track is enough, since we just want the artist ID.
#     - Each track in the results has an associated 'artists' field. This field is a list containing details about all artists involved in that track.
#    - For most tracks, especially those by a single artist, this list will contain one artist. From this artist's details, you can extract the 'id' field, which is the unique identifier for that artist on Spotify.
#
#
# 3. **Fetching Related Artists**:
#     - Once you have the artist's ID, you can use another SpotiPy method to fetch related artists. Think about which SpotiPy method allows you to get related artists using an artist's ID. Here is the documentation link: https://spotipy.readthedocs.io/en/2.22.1/.
#     - This method will return a list of related artists. You'll need to extract the relevant details (artist names) from this list.
#
# 4. **Iterating for Multiple Artists**:
#     - Once you have a function that returns related artists names for one artist, you can use a list comprehension to apply this function to a list of artist names.
#
# 5. **Testing**:
#     - Always test your function with one artist name first. Once you're confident it works, then apply it to the entire list.
#
# Remember, the key is to break the problem down into manageable steps. Use the SpotiPy documentation as a resource to understand available methods and their return structures.

# %% [markdown]
# ## Playlists
#
# The `sp.featured_playlists()` method in `spotipy` fetches a list of Spotify's featured playlists at a given moment. These are curated playlists that Spotify often highlights on the platform's homepage. The method provides a snapshot of the playlists that are being promoted or featured by Spotify at the time of the request.
#
# Once you've fetched the featured playlists, you can extract their IDs (and other details).

# %%
playlists_x = sp.featured_playlists() # We get a playlist id of a playlist we like

# %%
type(playlists_x)
# Out:
# dict

# %%
len(playlists_x)
# Out:
# 2

# %%
playlists_x.keys()
# Out:
# dict_keys(['message', 'playlists'])

# %%
playlists_x["playlists"]
# Out:
# {'href': 'https://api.spotify.com/v1/browse/featured-playlists?offset=0&limit=20',
#  'items': [{'collaborative': False,
#    'description': 'Los hits de ahora en la playlist más grande de España. Feat. KAROL G',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXaxEKcoCdWHD'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXaxEKcoCdWHD',
#    'id': '37i9dQZF1DXaxEKcoCdWHD',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f0000000255001bf9fd87087a183f3881',
#      'width': None}],
#    'name': 'Éxitos España',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': '#FFFFFF',
#    'public': True,
#    'snapshot_id': 'Zp45CgAAAAAwg7qrQNH5Uf7XjeFGeJbO',
# ...

# %% [markdown]
# ### Getting a Playlist's Details
# To fetch details about a specific playlist, you can use the playlist method. You'll need the playlist's Spotify ID.

# %% [markdown]
# In this example, we will use the following playlist id: *37i9dQZF1DXd9zR7tdziuQ*

# %%
playlist_id = "37i9dQZF1DXd9zR7tdziuQ"
playlist = sp.playlist(playlist_id)

# %%
print(playlist['name'])  # Print the playlist's name
print(playlist['description'])  # Print the playlist's description
# Out:
# Hits acústicos
# Relájate con tus canciones favoritas en versión acústica / Descontrai com versões acústicas das tuas músicas preferidas.

# %% [markdown]
# ### Getting Tracks from a Playlist
# If you want to get the tracks from a specific playlist, you can use the playlist_tracks method.

# %%
tracks = sp.playlist_tracks(playlist_id)
for track in tracks['items']:
    print(track['track']['name'])  # Print each track's name
# Out:
# Take Me Home, Country Roads
# La Vie En Rose
# You Are My Sunshine
# Sunday Morning - Acoustic
# Too Good At Goodbyes - Acoustic
# I'm Not the Only One - Live from Spotify, London
# True Colours
# Cold Heart - Acoustic
# September Song - Guitar Acoustic
# Collide - Acoustic Version
# Baby One More Time - Recorded at Spotify Studios New York City
# If You Ever Wanna Be In Love - James Bay Spotify Session 2015
# When You Love Someone - Acoustic
# Rockabye - Acoustic Version
# Blinding Lights
# Ain't Nobody (Loves Me Better) - Acoustic
# Little Talks
# What About Us - Acoustic
# Let It Go - James Bay Spotify Session 2015
# Shape of You - Acoustic
# Something Just Like This - Acoustic
# Linger
# Heaven Is a Place on Earth
# Wild Love - Acoustic
# Perfect - Acoustic
# 1973 - Acoustic
# Billie Jean
# Crazy in Love
# Naked - Acoustic Version
# Firestone - Live Acoustic Version
# Can't Help Falling in Love
# Fix You - Live
# Slow Dancing in a Burning Room - Acoustic
# ...

# %% [markdown]
# ### Getting Artists from a Playlist
#
# To extract all the artists from the tracks in a playlist, you'd typically follow these steps:
#
# 1. Fetch the playlist's tracks.
# 2. Iterate through each track.
# 3. For each track, extract the associated artists.

# %%
# List to store unique artist names
artists_list = []

for track_item in tracks['items']:
    track = track_item['track']
    for artist in track['artists']:
        artist_name = artist['name']
        if artist_name not in artists_list:  # This ensures each artist is added only once
            artists_list.append(artist_name)

print(artists_list)
# Out:
# ['Lana Del Rey', 'Daniela Andrade', 'Jasmine Thompson', 'Maroon 5', 'Sam Smith', 'Dua Lipa', 'Tom Odell', 'Elton John', 'JP Cooper', 'Howie Day', 'Ed Sheeran', 'James Bay', 'James TW', 'The Mayries', 'Ouvindo', 'Julia Sheer', 'Jon D', 'Thomas Daniel', 'Missy & Blonde', 'Julia Ross', 'Freedom Fry', 'James Blunt', 'The Civil Wars', 'James Arthur', 'Kygo', 'Conrad Sewell', 'Kacey Musgraves', 'John Mayer', 'Jessie J', 'The Wind and The Wave', 'Megan Davies', 'Keelan Donovan', 'Lotte Kestner', 'Halloran & Kate', 'Calum Scott', 'John Legend', 'Joy Williams', 'Sixpence None The Richer', 'The Lumineers', 'Obadiah Parker', 'Lily Allen', 'Frente!', 'Molly Parden', 'Hollow Hum', 'Gavin James', 'Sara Farell', 'Daniel Powter', 'Joanna Wang', 'William Fitzsimmons', 'Niall Horan', 'Sia', 'Becca Adams', 'Lykke Li', 'Sarah Jarosz', 'Alex Cornell', 'Rachel Brown', 'Kyle Nachtigal', 'Rita Ora', 'Clementine Duo', "Israel Kamakawiwo'ole", 'Arlo Parks', 'Sunset & Highland', 'Jaclyn Davies', 'Catey Shaw', 
# ...

# %% [markdown]
# ## Exercise 2: Unraveling the World of Playlists
#
#
# 1. **Featured Exploration**:
#    - Fetch the list of Spotify's current featured playlists.
#    - Extract and display the names and IDs of the top 5 featured playlists.

# %%
playlists_x = sp.featured_playlists() # We get a playlist id of a playlist we like

# %%
playlists_x
# Out:
# {'message': 'Popular Playlists',
#  'playlists': {'href': 'https://api.spotify.com/v1/browse/featured-playlists?offset=0&limit=20',
#   'items': [{'collaborative': False,
#     'description': 'Los hits de ahora en la playlist más grande de España. Feat. KAROL G',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXaxEKcoCdWHD'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXaxEKcoCdWHD',
#     'id': '37i9dQZF1DXaxEKcoCdWHD',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000255001bf9fd87087a183f3881',
#       'width': None}],
#     'name': 'Éxitos España',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#FFFFFF',
#     'public': True,
# ...

# %%
url ='https://api.spotify.com/v1/playlists/37i9dQZF1DZ06evO4e5iLu/tracks'

# %%
playlist_names = []
for i in playlists_x['playlists']['items']:
    playlist_names.append(i['name'])

playlist_names
# Out:
# ['Éxitos España',
#  'Viva Latino',
#  'PEGAO',
#  'Verano 2024',
#  'This Is KAROL G',
#  'Viral España 2024',
#  'Pop con Ñ',
#  'Flamenco Pop',
#  'temardos',
#  'Los 2000 España',
#  'BARRAS',
#  'Flamenco + Flow',
#  'míticas',
#  'Novedades Viernes España',
#  'Canta en el coche',
#  'Today’s Top Hits',
#  'MANSIÓN REGGAETÓN',
#  'Summer Dance Hits 2024',
#  'Todo Indie',
#  'Los 90 España']

# %%
playlists = playlists_x["playlists"]["items"]
playlists[0]['description']
# Out:
# 'Los hits de ahora en la playlist más grande de España. Feat. KAROL G'

# %%
playlists[0]['id']
# Out:
# '37i9dQZF1DXaxEKcoCdWHD'

# %%
# Keys = ID and Values = name

id_name_dict = {}
i = 1
for i in range(5):
    id_name_dict[playlists[i]['id']] = playlists[i]['name']
    
id_name_dict
# Out:
# {'37i9dQZF1DXaxEKcoCdWHD': 'Éxitos España',
#  '37i9dQZF1DX10zKzsJ2jva': 'Viva Latino',
#  '37i9dQZF1DX1HCSfq0nSal': 'PEGAO',
#  '37i9dQZF1DX9gKTxAbfFfX': 'Verano 2024',
#  '37i9dQZF1DZ06evO4e5iLu': 'This Is KAROL G'}

# %% [markdown]
#
# 2. **Deep Dive**:
#    - Choose any one of the top 5 featured playlists (you can choose the one you personally find most interesting or simply pick one randomly).
#    - Fetch and display its name, description, and total track count.

# %%
def get_playlist_description(playlist_id, data):
    playlists = data['playlists']['items']
    for playlist in playlists:
        if playlist['id'] == playlist_id:
            return playlist['description']
    return "Playlist not found"

# %%
playlist_id = "37i9dQZF1DX1HCSfq0nSal"

name = id_name_dict[playlist_id]
description = get_playlist_description(playlist_id,playlists_x) 
print(name)
print(description)
# Out:
# PEGAO
# Si está pegao, está aquí. Feat. Beny Jr

# %%
results = sp.playlist_tracks(playlist_id)

# Extract top 5 tracks
top_5_tracks = []
for idx, item in enumerate(results['items']):
    if idx < 10:
        track = item['track']
        top_5_tracks.append({'name': track['name'], 'artist': track['artists'][0]['name']})

# Print the top 5 tracks
print(top_5_tracks)
# Out:
# [{'name': 'Luna llena', 'artist': 'Beny Jr'}, {'name': 'Goteras', 'artist': 'Omar Montes'}, {'name': 'CLIMA (with Foreign Teck)', 'artist': 'Dei V'}, {'name': 'Whisky', 'artist': 'Samuel G'}, {'name': 'YOTULOKO', 'artist': 'Omar Montes'}, {'name': 'Tu Silueta', 'artist': 'Diegote'}, {'name': 'QLONA', 'artist': 'KAROL G'}, {'name': '2xLL', 'artist': 'JC Reyes'}, {'name': 'Baby Demon', 'artist': 'Anuel AA'}, {'name': 'TU$$I (with Dei V)', 'artist': 'YOVNGCHIMI'}]

# %% [markdown]
# 3. **Track-tastic**:
#    - Extract and display the names of the first 10 tracks in the chosen playlist.
#
# 4. **Artistic Flair**:
#    - Create a dictionary where the keys are the names of the first 10 tracks, and the values are lists containing the names of the artists associated with each track.
#    - For example: `{"TrackName1": ["Artist1", "Artist2"], "TrackName2": ["Artist3"]}`

# %%
# Your answer here
